# %% [markdown]
# # U2A1. Operaciones Matriciales y Vectoriales
#
# ## Elaborado por: Gabriel Carrizales
#
# ### Fecha: 22/09/2025
#
# #### Materia: Robótica
#
# ##### Docente: ING. Osbaldo Aragón Banderas

# %% [markdown]
# # Introducción
#
# Este notebook contiene el desarrollo de **10 ejercicios** de álgebra lineal utilizando Python, con el apoyo de las librerías `numpy` y `sympy`.
# El objetivo es reforzar el uso de operaciones matriciales y vectoriales, que son fundamentales en la ingeniería y en la robótica
#
# A lo largo de este notebook se realizan las siguientes actividades:
#
# 1. **Suma de matrices**
# 2. **Multiplicación de matrices**
# 3. **Inversión de matriz**
# 4. **Resolución de sistemas de ecuaciones lineales**
# 5. **Cálculo de determinante**
# 6. **Producto cruz de vectores**
# 7. **Proyección ortogonal**
# 8. **Producto escalar de proyecciones**
# 9. **Ortogonalización de Gram–Schmidt**
# 10. **Cálculo de espacio nulo**
#
# Cada ejercicio incluye:
# - Una breve explicación del problema.
# - El código necesario para resolverlo.
# - La salida correspondiente.
#
# De esta manera, el notebook no solo muestra los resultados, sino que también sirve como **guía práctica** para aprender a implementar operaciones de álgebra lineal en Python.

# %% [markdown]
# ## Objetivo General
# Aplicar los conceptos de álgebra lineal mediante el uso de Python en Jupyter Notebook, resolviendo problemas de operaciones matriciales y vectoriales que fortalezcan la comprensión teórica y la habilidad práctica en programación científica.
#
# ## Objetivos Específicos
# - Implementar operaciones básicas de matrices como suma, multiplicación, determinante e inversa.
# - Resolver sistemas de ecuaciones lineales utilizando métodos matriciales.
# - Calcular productos vectoriales como el producto cruz y el producto escalar.
# - Determinar proyecciones ortogonales de vectores en distintos subespacios.
# - Aplicar el proceso de ortogonalización de Gram–Schmidt para generar conjuntos ortogonales.
# - Identificar la base del espacio nulo de una matriz a partir de su forma reducida.
# - Desarrollar habilidades en el uso de librerías matemáticas de Python (`numpy` y `sympy`).
# - Fortalecer la conexión entre teoría matemática y aplicaciones computacionales en ingeniería.

# %%
pip install notebook numpy sympy
# Out:
# Requirement already satisfied: notebook in c:\users\gabri\anaconda3\lib\site-packages (7.4.5)
# Requirement already satisfied: numpy in c:\users\gabri\anaconda3\lib\site-packages (1.26.4)
# Requirement already satisfied: sympy in c:\users\gabri\anaconda3\lib\site-packages (1.13.2)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\gabri\anaconda3\lib\site-packages (from notebook) (2.14.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\gabri\anaconda3\lib\site-packages (from notebook) (2.27.3)
# Requirement already satisfied: jupyterlab<4.5,>=4.4.5 in c:\users\gabri\anaconda3\lib\site-packages (from notebook) (4.4.7)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\gabri\anaconda3\lib\site-packages (from notebook) (0.2.3)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\gabri\anaconda3\lib\site-packages (from notebook) (6.4.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\gabri\anaconda3\lib\site-packages (from sympy) (1.3.0)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\gabri\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (4.2.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\gabri\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (21.3.0)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\gabri\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (3.1.4)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\gabri\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\gabri\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.7.2)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\gabri\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\gabri\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\gabri\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (7.16.4)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\gabri\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\gabri\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (7.4.0)
# Requirement already satisfied: packaging>=22.0 in c:\users\gabri\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (24.1)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\gabri\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.14.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\gabri\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (2.0.10)
# Requirement already satisfied: pyzmq>=24 in c:\users\gabri\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (25.1.2)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\gabri\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\gabri\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.17.1)
# Requirement already satisfied: traitlets>=5.6.0 in c:\users\gabri\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.14.3)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\gabri\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\gabri\anaconda3\lib\site-packages (from jupyterlab<4.5,>=4.4.5->notebook) (2.0.4)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\users\gabri\anaconda3\lib\site-packages (from jupyterlab<4.5,>=4.4.5->notebook) (0.27.0)
# Requirement already satisfied: ipykernel!=6.30.0,>=6.5.0 in c:\users\gabri\anaconda3\lib\site-packages (from jupyterlab<4.5,>=4.4.5->notebook) (6.28.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\gabri\anaconda3\lib\site-packages (from jupyterlab<4.5,>=4.4.5->notebook) (2.2.0)
# Requirement already satisfied: setuptools>=41.1.0 in c:\users\gabri\anaconda3\lib\site-packages (from jupyterlab<4.5,>=4.4.5->notebook) (75.1.0)
# Requirement already satisfied: babel>=2.10 in c:\users\gabri\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\gabri\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (0.9.6)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\gabri\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (4.23.0)
# Requirement already satisfied: requests>=2.31 in c:\users\gabri\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (2.32.3)
# Requirement already satisfied: idna>=2.8 in c:\users\gabri\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\gabri\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\gabri\anaconda3\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (21.2.0)
# Requirement already satisfied: pytz>=2015.7 in c:\users\gabri\anaconda3\lib\site-packages (from babel>=2.10->jupyterlab-server<3,>=2.27.1->notebook) (2024.1)
# Requirement already satisfied: certifi in c:\users\gabri\anaconda3\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab<4.5,>=4.4.5->notebook) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\gabri\anaconda3\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab<4.5,>=4.4.5->notebook) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\gabri\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab<4.5,>=4.4.5->notebook) (0.14.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\gabri\anaconda3\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\gabri\anaconda3\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\gabri\anaconda3\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook) (8.27.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\gabri\anaconda3\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\gabri\anaconda3\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook) (1.6.0)
# Requirement already satisfied: psutil in c:\users\gabri\anaconda3\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook) (5.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\gabri\anaconda3\lib\site-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.4.0->notebook) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\gabri\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\gabri\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\gabri\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\gabri\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (0.10.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\gabri\anaconda3\lib\site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\gabri\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\gabri\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook) (305.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\gabri\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\gabri\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (6.0.1)
# Requirement already satisfied: rfc3339-validator in c:\users\gabri\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\gabri\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\gabri\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\gabri\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\gabri\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\gabri\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.1.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\gabri\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\gabri\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\gabri\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (1.5.0)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\gabri\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (2.15.1)
# Requirement already satisfied: tinycss2 in c:\users\gabri\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (1.2.1)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\gabri\anaconda3\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook) (2.16.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gabri\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gabri\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook) (2.2.3)
# Requirement already satisfied: six>=1.9.0 in c:\users\gabri\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\gabri\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.5.1)
# Requirement already satisfied: decorator in c:\users\gabri\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\gabri\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\gabri\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook) (3.0.43)
# Requirement already satisfied: stack-data in c:\users\gabri\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook) (0.2.0)
# Requirement already satisfied: colorama in c:\users\gabri\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook) (0.4.6)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook)
#   Downloading fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook)
#   Downloading isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\gabri\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (2.1)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook)
#   Downloading uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=24.6.0 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook)
#   Downloading webcolors-24.11.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\gabri\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\gabri\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (2.5)
# Requirement already satisfied: pycparser in c:\users\gabri\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (2.21)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\gabri\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\gabri\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook) (0.2.5)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\gabri\anaconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (1.2.3)
# Requirement already satisfied: executing in c:\users\gabri\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\gabri\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\gabri\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook) (0.2.2)
# Downloading webcolors-24.11.1-py3-none-any.whl (14 kB)
# Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Installing collected packages: webcolors, uri-template, fqdn, isoduration
# Successfully installed fqdn-1.5.1 isoduration-20.11.0 uri-template-1.3.0 webcolors-24.11.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# Celda 0: imports y configuración básica
import numpy as np
from sympy import Matrix, Rational

# Opcional: mayor precisión de impresión si lo deseas
np.set_printoptions(precision=8, suppress=True)

# %% [markdown]
# # Ejercicio 1: Suma de matrices
# Objetivo: Sumar las matrices A y B y mostrar la matriz resultante C = A + B.

# %%
# Ejercicio 1 - Suma de matrices
A = np.array([[2, 4, 6],
              [1, 3, 5],
              [7, 9, 11]])
B = np.array([[12, 10, 8],
              [6, 4, 2],
              [0, -2, -4]])
C = A + B
print("A:\n", A)
print("B:\n", B)
print("C = A + B =\n", C)
# Out:
# A:
#  [[ 2  4  6]
#  [ 1  3  5]
#  [ 7  9 11]]
# B:
#  [[12 10  8]
#  [ 6  4  2]
#  [ 0 -2 -4]]
# C = A + B =
#  [[14 14 14]
#  [ 7  7  7]
#  [ 7  7  7]]

# %% [markdown]
# # Ejercicio 2: Multiplicación de matrices
# Objetivo: Multiplicar A * B donde A es 3x2 y B es 2x2. Mostrar la matriz resultante C.

# %%
# Ejercicio 2 - Multiplicación de matrices
A = np.array([[2, 1],
              [3, 4],
              [5, 6]])
B = np.array([[7, 8],
              [9, 10]])
C = A @ B   # o np.dot(A, B)
print("A:\n", A)
print("B:\n", B)
print("C = A * B =\n", C)
# Out:
# A:
#  [[2 1]
#  [3 4]
#  [5 6]]
# B:
#  [[ 7  8]
#  [ 9 10]]
# C = A * B =
#  [[ 23  26]
#  [ 57  64]
#  [ 89 100]]

# %% [markdown]
# # Ejercicio 3: Inversión de matriz
# Objetivo: Calcular la inversa de la matriz cuadrada A. Mostraremos una versión numérica (float) y la inversa exacta con fracciones usando sympy.

# %%
# Ejercicio 3 - Inversa de A (numérica y exacta)
A = np.array([[4, 7, 2],
              [2, 6, 8],
              [3, 1, 9]])

# inversa numérica
A_inv_num = np.linalg.inv(A)
print("Inversa (numpy, float):\n", A_inv_num)

# inversa exacta con sympy (fracciones)
A_sym = Matrix([[4,7,2],[2,6,8],[3,1,9]])
A_inv_exact = A_sym.inv()
print("\nInversa exacta (sympy):\n", A_inv_exact)
# Out:
# Inversa (numpy, float):
#  [[ 0.2371134  -0.31443299  0.22680412]
#  [ 0.03092784  0.15463918 -0.1443299 ]
#  [-0.08247423  0.08762887  0.05154639]]
#
# Inversa exacta (sympy):
#  Matrix([[23/97, -61/194, 22/97], [3/97, 15/97, -14/97], [-8/97, 17/194, 5/97]])

# %% [markdown]
# # Ejercicio 4: Resolución de sistema de ecuaciones lineales
# Sistema:
# 2x + y + z = 8
# 3x + 5y + 2z = 21
# x + 2y + 4z = 11
#
# Se escribe AX = B y se resuelve para X = [x, y, z]. Mostraremos solución numérica y exacta.

# %%
# Ejercicio 4 - Resolución del sistema AX = B
A = np.array([[2, 1, 1],
              [3, 5, 2],
              [1, 2, 4]])
B = np.array([8, 21, 11])

# solución numérica
X = np.linalg.solve(A, B)
print("Solución numérica X =\n", X)

# solución exacta con sympy (fracciones)
A_sym = Matrix([[2,1,1],[3,5,2],[1,2,4]])
B_sym = Matrix([8,21,11])
X_sym = A_sym.LUsolve(B_sym)
print("\nSolución exacta (fracciones):\n", X_sym)
# Out:
# Solución numérica X =
#  [2.30434783 2.43478261 0.95652174]
#
# Solución exacta (fracciones):
#  Matrix([[53/23], [56/23], [22/23]])

# %% [markdown]
# # Ejercicio 5: Cálculo de determinante
# Objetivo: Calcular el determinante de la matriz A.

# %%
# Ejercicio 5 - Determinante
A = np.array([[3, -2, 1],
              [0, 5, 4],
              [2, 1, 7]])
det_A = np.linalg.det(A)
print("Determinante (float):", det_A)

# si quieres el valor exacto con sympy:
A_sym = Matrix([[3,-2,1],[0,5,4],[2,1,7]])
det_exact = A_sym.det()
print("Determinante exacto (sympy):", det_exact)
# Out:
# Determinante (float): 67.00000000000004
# Determinante exacto (sympy): 67

# %% [markdown]
# # Ejercicio 6: Producto cruz de vectores
# Dados A y B en R^3, calcular A x B.

# %%
# Ejercicio 6 - Producto cruz
A = np.array([2, 3, -1])
B = np.array([1, -2, 4])
cross = np.cross(A, B)
print("A x B =\n", cross)
# Out:
# A x B =
#  [10 -9 -7]

# %% [markdown]
# # Ejercicio 7: Proyección ortogonal
# Calcular la proyección de V sobre U: proj_U(V) = (V·U / U·U) * U

# %%
# Ejercicio 7 - Proyección ortogonal
V = np.array([5, -3, 2])
U = np.array([2, 1, 2])
factor = np.dot(V, U) / np.dot(U, U)
proj_V_on_U = factor * U
print("Factor (V·U / U·U) =", factor)
print("Proyección de V sobre U =", proj_V_on_U)

# Forma exacta con sympy
V_sym = Matrix([5,-3,2])
U_sym = Matrix([2,1,2])
proj_exact = (V_sym.dot(U_sym) / U_sym.dot(U_sym)) * U_sym
print("Proyección exacta (sympy):", proj_exact)
# Out:
# Factor (V·U / U·U) = 1.2222222222222223
# Proyección de V sobre U = [2.44444444 1.22222222 2.44444444]
# Proyección exacta (sympy): Matrix([[22/9], [11/9], [22/9]])

# %% [markdown]
# # Ejercicio 8: Producto escalar de proyecciones
# Dados V, U, W, calcule el producto escalar entre proj_U(V) y proj_W(V).

# %%
# Ejercicio 8 - Producto escalar de proyecciones
V = np.array([3, -1, 2])
U = np.array([2, 2, -1])
W = np.array([1, 4, -2])

proj_VU = (np.dot(V, U) / np.dot(U, U)) * U
proj_VW = (np.dot(V, W) / np.dot(W, W)) * W
dot_proj = np.dot(proj_VU, proj_VW)

print("proj_V_on_U =", proj_VU)
print("proj_V_on_W =", proj_VW)
print("Producto escalar entre las proyecciones =", dot_proj)

# exacto con sympy
V_sym = Matrix([3,-1,2])
U_sym = Matrix([2,2,-1])
W_sym = Matrix([1,4,-2])
proj_VU_sym = (V_sym.dot(U_sym)/U_sym.dot(U_sym))*U_sym
proj_VW_sym = (V_sym.dot(W_sym)/W_sym.dot(W_sym))*W_sym
dot_exact = proj_VU_sym.dot(proj_VW_sym)
print("Producto escalar exacto (sympy):", dot_exact)
# Out:
# proj_V_on_U = [ 0.44444444  0.44444444 -0.22222222]
# proj_V_on_W = [-0.23809524 -0.95238095  0.47619048]
# Producto escalar entre las proyecciones = -0.6349206349206349
# Producto escalar exacto (sympy): -40/63

# %% [markdown]
# # Ejercicio 9: Ortogonalización de Gram–Schmidt
# Dado el conjunto de vectores v1, v2, v3, aplicar Gram–Schmidt para obtener un conjunto ortogonal.
# (No normalizamos, solo obtenemos vectores ortogonales).

# %%
# Ejercicio 9 - Gram-Schmidt
def gram_schmidt(vectors):
    ortogonales = []
    for v in vectors:
        w = v.astype(float).copy()
        for u in ortogonales:
            proj = (np.dot(v, u) / np.dot(u, u)) * u
            w = w - proj
        ortogonales.append(w)
    return ortogonales

v1 = np.array([1,1,0], dtype=float)
v2 = np.array([1,2,1], dtype=float)
v3 = np.array([2,1,3], dtype=float)

ort = gram_schmidt([v1, v2, v3])
for i, vec in enumerate(ort, 1):
    print(f"u{i} (ortogonal) =", vec)

# resultado exacto (fracciones) con sympy
v1s = Matrix([1,1,0])
v2s = Matrix([1,2,1])
v3s = Matrix([2,1,3])
def gs_sympy(vs):
    ort = []
    for v in vs:
        w = v
        for u in ort:
            w = w - (v.dot(u)/u.dot(u))*u
        ort.append(w)
    return ort

ort_sym = gs_sympy([v1s, v2s, v3s])
print("\nOrtogonales exactos (sympy):")
for vec in ort_sym:
    print(vec)
# Out:
# u1 (ortogonal) = [1. 1. 0.]
# u2 (ortogonal) = [-0.5  0.5  1. ]
# u3 (ortogonal) = [ 1.33333333 -1.33333333  1.33333333]
#
# Ortogonales exactos (sympy):
# Matrix([[1], [1], [0]])
# Matrix([[-1/2], [1/2], [1]])
# Matrix([[4/3], [-4/3], [4/3]])

# %% [markdown]
# # Ejercicio 10: Espacio nulo
# Dada la matriz en forma escalonada reducida por filas, encuentra una base para el espacio nulo (soluciones de A v = 0).

# %%
# Ejercicio 10 - Espacio nulo (nullspace) con sympy
A = Matrix([[1, 2, 0, 3],
            [0, 1, 0, 2],
            [0, 0, 1, 1]])
null_space = A.nullspace()
print("Base del espacio nulo (cada vector columna es una base):")
for v in null_space:
    print(v)
# Explicación: la solución general es t * (vector_impreso) donde t es un escalar.
# Out:
# Base del espacio nulo (cada vector columna es una base):
# Matrix([[1], [-2], [-1], [1]])

# %% [markdown]
# # Respuestas analíticas
#
# **Ejercicio 1 — Suma de matrices**
# A + B = C, donde
#
# A = $\begin{pmatrix}2 & 4 & 6\\[4pt]1 & 3 & 5\\[4pt]7 & 9 & 11\end{pmatrix}$,
# B = $\begin{pmatrix}12 & 10 & 8\\[4pt]6 & 4 & 2\\[4pt]0 & -2 & -4\end{pmatrix}$
#
# $$
# C = A + B =
# \begin{pmatrix}
# 14 & 14 & 14\\[4pt]
# 7  & 7  & 7\\[4pt]
# 7  & 7  & 7
# \end{pmatrix}
# $$
#
# ---
#
# **Ejercicio 2 — Multiplicación de matrices**
# A (3×2) · B (2×2) = C (3×2), con
#
# A = $\begin{pmatrix}2 & 1\\[4pt]3 & 4\\[4pt]5 & 6\end{pmatrix}$,
# B = $\begin{pmatrix}7 & 8\\[4pt]9 & 10\end{pmatrix}$
#
# $$
# C = A\cdot B =
# \begin{pmatrix}
# 23 & 26\\[4pt]
# 57 & 64\\[4pt]
# 89 & 100
# \end{pmatrix}
# $$
#
# ---
#
# **Ejercicio 3 — Inversa de la matriz A**
# A = $\begin{pmatrix}4 & 7 & 2\\[4pt]2 & 6 & 8\\[4pt]3 & 1 & 9\end{pmatrix}$
#
# La inversa exacta (entrada a entrada en fracciones) es:
#
# $$
# A^{-1} =
# \begin{pmatrix}
# \frac{23}{97} & -\frac{61}{194} & \frac{22}{97}\\[6pt]
# \frac{3}{97}  & \frac{15}{97}   & -\frac{14}{97}\\[6pt]
# -\frac{8}{97} & \frac{17}{194}  & \frac{5}{97}
# \end{pmatrix}
# $$
#
# (Se puede multiplicar numéricamente para obtener aproximaciones decimales si lo prefieres.)
#
# ---
#
# **Ejercicio 4 — Resolución del sistema lineal**
# Sistema:
#
# $$
# \begin{cases}
# 2x + y + z = 8\\[4pt]
# 3x + 5y + 2z = 21\\[4pt]
# x + 2y + 4z = 11
# \end{cases}
# $$
#
# En forma matricial $AX=B$. La solución exacta (fracciones) es:
#
# $$
# X =
# \begin{pmatrix}
# x\\[4pt] y\\[4pt] z
# \end{pmatrix}
# =
# \begin{pmatrix}
# \frac{53}{23}\\[4pt]
# \frac{56}{23}\\[4pt]
# \frac{22}{23}
# \end{pmatrix}
# $$
#
# (siendo en decimal: $x\approx 2.3043,\; y\approx 2.4348,\; z\approx 0.9565$.)
#
# ---
#
# **Ejercicio 5 — Determinante**
# A = $\begin{pmatrix}3 & -2 & 1\\[4pt]0 & 5 & 4\\[4pt]2 & 1 & 7\end{pmatrix}$
#
# $$
# \det(A) = 67
# $$
#
# ---
#
# **Ejercicio 6 — Producto cruz de vectores**
# A = $[2,\,3,\,-1]$, B = $[1,\,-2,\,4]$
#
# $$
# A \times B =
# \begin{pmatrix}10\\[4pt]-9\\[4pt]-7\end{pmatrix}
# $$
#
# ---
#
# **Ejercicio 7 — Proyección ortogonal de V sobre U**
# V = $[5,\,-3,\,2]$, U = $[2,\,1,\,2]$
#
# $$
# \operatorname{proj}_U(V) = \left(\frac{V\cdot U}{U\cdot U}\right) U
# = \frac{22}{9}\begin{pmatrix}1\\[4pt]\tfrac{1}{2}\\[4pt]1\end{pmatrix}
# =
# \begin{pmatrix}\tfrac{22}{9}\\[6pt]\tfrac{11}{9}\\[6pt]\tfrac{22}{9}\end{pmatrix}
# $$
#
# (aprox.: $[2.4444,\;1.2222,\;2.4444]$.)
#
# ---
#
# **Ejercicio 8 — Producto escalar de proyecciones**
# V = $[3,\,-1,\,2]$, U = $[2,\,2,\,-1]$, W = $[1,\,4,\,-2]$
#
# Primero las proyecciones:
#
# $$
# \operatorname{proj}_{U}(V)=
# \begin{pmatrix}\tfrac{4}{9}\\[4pt]\tfrac{4}{9}\\[4pt]-\tfrac{2}{9}\end{pmatrix},\qquad
# \operatorname{proj}_{W}(V)=
# \begin{pmatrix}-\tfrac{5}{21}\\[4pt]-\tfrac{20}{21}\\[4pt]\tfrac{10}{21}\end{pmatrix}
# $$
#
# El producto escalar entre ambas proyecciones es:
#
# $$
# \operatorname{proj}_U(V)\cdot\operatorname{proj}_W(V) = -\frac{40}{63}
# \approx -0.63492
# $$
#
# ---
#
# **Ejercicio 9 — Ortogonalización (Gram–Schmidt)**
# Vectores originales:
# $v_1=[1,1,0],\; v_2=[1,2,1],\; v_3=[2,1,3]$.
#
# Aplicando Gram–Schmidt (sin normalizar) se obtiene el conjunto ortogonal:
#
# $$
# u_1 = \begin{pmatrix}1\\[4pt]1\\[4pt]0\end{pmatrix},\qquad
# u_2 = \begin{pmatrix}-\tfrac{1}{2}\\[6pt]\tfrac{1}{2}\\[6pt]1\end{pmatrix},\qquad
# u_3 = \begin{pmatrix}\tfrac{4}{3}\\[6pt]-\tfrac{4}{3}\\[6pt]\tfrac{4}{3}\end{pmatrix}
# $$
#
# Puedes verificar que $u_i\cdot u_j = 0$ para $i\neq j$.
#
# ---
#
# **Ejercicio 10 — Espacio nulo (nullspace)**
# Matriz en RREF:
#
# $$
# A = \begin{pmatrix}
# 1 & 2 & 0 & 3\\[4pt]
# 0 & 1 & 0 & 2\\[4pt]
# 0 & 0 & 1 & 1
# \end{pmatrix}
# $$
#
# Base del espacio nulo (cada vector columna es un generador):
#
# $$
# \text{Null}(A) = \operatorname{span}\left\{
# \begin{pmatrix}1\\[4pt]-2\\[4pt]-1\\[4pt]1\end{pmatrix}
# \right\}
# $$
#
# Es decir, la solución general de $Av=0$ es $v = t\begin{pmatrix}1\\-2\\-1\\1\end{pmatrix}$, $t\in\mathbb{R}$.

# %% [markdown]
# # Conclusión
#
# A lo largo de esta práctica se aplicaron distintos conceptos de álgebra lineal mediante ejercicios resueltos en Python dentro de Jupyter Notebook, reforzando la comprensión de operaciones con matrices y vectores. Se comprobó cómo las operaciones básicas, como suma, multiplicación, determinantes e inversas, son fundamentales para resolver problemas más complejos como sistemas de ecuaciones, proyecciones o el cálculo de espacios nulos.
#
# Además, se evidenció la utilidad de métodos como la ortogonalización de Gram–Schmidt, que permite construir bases ortogonales para facilitar cálculos posteriores, así como la importancia de interpretar de manera analítica y numérica cada resultado.
#
# En conclusión, esta práctica no solo fortaleció el dominio de las técnicas algebraicas, sino que también mostró la relevancia de su aplicación en programación y simulación, herramientas indispensables en la ingeniería para modelar y resolver problemas reales de manera eficiente y precisa.
